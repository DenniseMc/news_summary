# %% [markdown]
# <a href="https://colab.research.google.com/github/DenniseMc/news_summary/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "lxml[html_clean]"

# %%
# !pip install readability-lxml

# %% [markdown]
# Get news API key

# %%
from google.colab import userdata
api_key = userdata.get('newsApiKey')

# %% [markdown]
# Import libraries

# %%
import requests
from bs4 import BeautifulSoup
from transformers import pipeline
from datetime import datetime
from dateutil.relativedelta import relativedelta
from readability import Document

# %% [markdown]
# Initialize the summarizer

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Functions

# %% [markdown]
# Get article content

# %%
# Define the URL
url = "https://economictimes.indiatimes.com/news/international/us/trump-casts-his-vote-on-election-day/articleshow/114990894.cms"

def get_article_content(url):

    # Fetch the HTML content of the first article
    article_response = requests.get(url)
    print(url)

    if article_response.status_code == 200:
        # Parse and extract the main content with Readability
        doc = Document(article_response.text)
        article_content = doc.summary()

        # Use BeautifulSoup to clean and format the extracted content
        soup = BeautifulSoup(article_content, 'html.parser')
        clean_text = soup.get_text(separator='\n', strip=True)

        # Print the clean article content
        return(clean_text)
    else:
        print(f"Failed to fetch the article HTML. Status code: {article_response.status_code}")
        return null

print(get_article_content(url))
# Out:
# https://economictimes.indiatimes.com/news/international/us/trump-casts-his-vote-on-election-day/articleshow/114990894.cms
# At his polling station in
# Florida
# , former President Trump cast his ballot in the 2024 election on Tuesday.
# Melania Trump
# , the former first lady, joined Trump, who fielded questions from reporters regarding the campaign's status and the likelihood that a winner would not be known by the end of the evening, as quoted in a report by The Hill.
# Trump told reporters that he ran a great campaign and had no regrets. It was perhaps the best of the three, in his opinion. In the first one, he performed admirably.
# In the second one, he performed significantly better, but something went wrong. And the best was this. This was their best campaign to date, as quoted in a report by The Hill.
# ...
